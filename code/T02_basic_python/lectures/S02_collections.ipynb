# %% [markdown]
# # Collections

# %%
# List

# Create a list of your favorite fruits
fruits = ["apple", "banana", "cherry"]
# fruits[0:2]

# Print the second fruit in the list.
# print(fruits[:2])
# print(fruits[1])

# Then add a new fruit to the list and print the updated list.
fruits.append("orange")
fruits.append("pineapple")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'pineapple']

# %%
# Dictionary

# Create a dictionary with three key-value pairs representing a person's name, age, and city.
person = {
    "name": "Alice",
    "age": 30,
    # "city": "New York",
    "address": {"city": "New York", "postal_code": 12334},
}

# person2 = {
#     "name": "Tom",
#     "age": 20,
#     "city": "Mass",
# }

# persons = [person1, person2]

# print(persons)

# Print the person's age.
person["age"]
person["address"]["city"]
person["name"]

# Add a new key-value pair for the person's profession and print the updated dictionary.

person["profession"] = "Engineer"
person["profession"] = "Secretary"

print(person)
# Out:
# {'name': 'Alice', 'age': 30, 'address': {'city': 'New York', 'postal_code': 12334}, 'profession': 'Secretary'}

# %%
{**person, "age": 40, "pet":"cat"}
# Out:
# {'name': 'Alice',
#  'age': 40,
#  'address': {'city': 'New York', 'postal_code': 12334},
#  'profession': 'Secretary',
#  'pet': 'cat'}

# %%
list1 = [1,2,3,4]
list2 = [*list1, 5, 6, 7, 8]
print(list2)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# Exercise 3: Tuple

# Create a tuple with three elements representing a book's title, author, and year published.
book = ("Title 1", "Author 2", 1956)

# Print the author's name.
print(book[2])

# Try to add a new element to the tuple and observe what happens.
# book.append("Hello")
# book[2] = "something else"

# Change the year published.
book = (*book[:2], 20000)

print(book)
# Out:
# 1956
# ('Title 1', 'Author 2', 20000)
