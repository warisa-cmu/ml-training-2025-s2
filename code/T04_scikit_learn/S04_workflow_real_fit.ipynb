# %%
import pickle
from datetime import datetime
from pprint import pp

import pandas as pd
from sklearn.base import BaseEstimator
from sklearn.model_selection import train_test_split

# %%
SAVE_DATA = False

# %% [markdown]
# ### Class definitions
#
# Note that in real production you should put this definition in a separate .py file and import it.
# For example
#
# ```python
# from classes_v1 import DataHandler, MyUtil, RegSwitcher
# ```

# %%
class MyUtil:
    @staticmethod
    def save_data(filename, data):
        with open(filename, "wb") as file:
            pickle.dump(data, file)

    @staticmethod
    def load_data(filename):
        with open(filename, "rb") as file:
            data = pickle.load(file)
        return data

    @staticmethod
    def get_dt():
        return datetime.now().strftime("%Y-%m-%d_%H-%M")

# %%
class DataHandler:
    def __init__(self, _X, _Y, scalerX, scalerY):
        self._X = _X
        self._Y = _Y
        self.scalerX = scalerX
        self.scalerY = scalerY
        self.X_train = None
        self.X_test = None
        self.Y_train = None
        self.Y_test = None

    def split_and_scale(self, test_size, random_state):
        _X_train, _X_test, _Y_train, _Y_test = train_test_split(
            self._X, self._Y, test_size=test_size, random_state=random_state
        )
        self.X_train = self.scalerX.fit_transform(_X_train)
        self.X_test = self.scalerX.transform(_X_test)

        self.Y_train = self.scalerY.fit_transform(_Y_train)
        self.Y_test = self.scalerY.transform(_Y_test)

    def get_train(self):
        return self.X_train, self.Y_train

    def get_test(self):
        return self.X_test, self.Y_test

# %%
class RegSwitcher(BaseEstimator):
    def __init__(self, base=None):
        self.base = base

    def fit(self, X, Y):
        self.base.fit(X, Y)
        self.is_fitted_ = True
        return self

    def predict(self, X):
        return self.base.predict(X)

# %%
dt = MyUtil.get_dt()

# %% [markdown]
# ### Read data

# %%
df = pd.read_excel("data.xlsx", index_col="exp")
df.head()
# Out:
#               m1           m2        m3  s1__autocorrelation__lag_8  \
# exp
# E001  150.223716  1176.177278  1.142097                   -0.305434
# E002  102.534268  1483.654982  1.104716                   -0.243785
# E003  119.890549  1254.897451  2.162773                   -0.329006
# E004  162.830799  1302.043195  1.308283                   -0.065152
# E005  165.720956  1154.482314  1.566830                   -0.304881
#
#       s1__autocorrelation__lag_9  s1__autocorrelation__lag_7  \
# exp
# E001                   -0.519191                   -0.074829
# E002                   -0.454262                   -0.021002
# E003                   -0.543405                   -0.095913
# E004                   -0.266498                    0.138913
# E005                   -0.518177                   -0.074836
#
#       s1__autocorrelation__lag_6  s1__autocorrelation__lag_5  \
# exp
# E001                    0.159896                    0.385790
# E002                    0.202836                    0.416423
# E003                    0.142612                    0.373002
# E004                    0.337187                    0.521401
# E005                    0.159321                    0.384728
#
#       s1__autocorrelation__lag_4  s1__longest_strike_above_mean  ...  \
# exp                                                              ...
# E001                    0.590387                             14  ...
# E002                    0.608972                             14  ...
# E003                    0.582151                             14  ...
# E004                    0.683873                             16  ...
# E005                    0.589003                             14  ...
#
#       s1__ar_coefficient__coeff_3__k_10  s1__approximate_entropy__m_2__r_0.1  \
# exp
# E001                           0.183996                             0.158567
# E002                           0.184370                             0.144742
# E003                           0.184036                             0.144268
# E004                           0.187213                             0.137326
# E005                           0.183978                             0.128546
#
#       s1__lempel_ziv_complexity__bins_3  s1__partial_autocorrelation__lag_4  \
# exp
# E001                           0.204152                           -0.360084
# E002                           0.203008                           -0.344364
# E003                           0.208163                           -0.364611
# E004                           0.193662                           -0.355441
# E005                           0.192440                           -0.357588
#
#       s1__fft_coefficient__attr_"abs"__coeff_7  \
# exp
# E001                                  0.293617
# E002                                  6.142373
# E003                                 26.783283
# E004                                 33.227591
# E005                                 11.439470
#
#       s1__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# exp
# E001                                         0.499488
# E002                                         0.477743
# E003                                         0.506435
# E004                                         0.460547
# E005                                         0.497940
#
#       s1__spkt_welch_density__coeff_2         y1        y2          y3
# exp
# E001                     5.886812e-08  55.460434  1.065917  114.578620
# E002                     3.643621e-06  50.640306  1.285666  124.651484
# E003                     1.590028e-04  50.832405  1.154859   57.018054
# E004                     7.926165e-04  62.476545  1.025161  132.221218
# E005                     1.462831e-04  57.634438  1.043776   92.160269
#
# [5 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, E001 to E100
# Data columns (total 50 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   m1                                                  100 non-null    float64
#  1   m2                                                  100 non-null    float64
#  2   m3                                                  100 non-null    float64
#  3   s1__autocorrelation__lag_8                          100 non-null    float64
#  4   s1__autocorrelation__lag_9                          100 non-null    float64
#  5   s1__autocorrelation__lag_7                          100 non-null    float64
#  6   s1__autocorrelation__lag_6                          100 non-null    float64
#  7   s1__autocorrelation__lag_5                          100 non-null    float64
#  8   s1__autocorrelation__lag_4                          100 non-null    float64
#  9   s1__longest_strike_above_mean                       100 non-null    int64
#  10  s1__autocorrelation__lag_3                          100 non-null    float64
#  11  s1__approximate_entropy__m_2__r_0.7                 100 non-null    float64
#  12  s1__longest_strike_below_mean                       100 non-null    int64
#  13  s1__autocorrelation__lag_2                          100 non-null    float64
#  14  s1__approximate_entropy__m_2__r_0.9                 100 non-null    float64
#  15  s1__permutation_entropy__dimension_3__tau_1         100 non-null    float64
#  16  s1__autocorrelation__lag_1                          100 non-null    float64
#  17  s1__partial_autocorrelation__lag_1                  100 non-null    float64
#  18  s1__permutation_entropy__dimension_5__tau_1         100 non-null    float64
#  19  s1__permutation_entropy__dimension_4__tau_1         100 non-null    float64
#  20  s1__permutation_entropy__dimension_6__tau_1         100 non-null    float64
#  21  s1__permutation_entropy__dimension_7__tau_1         100 non-null    float64
#  22  s1__cid_ce__normalize_True                          100 non-null    float64
#  23  s1__approximate_entropy__m_2__r_0.3                 100 non-null    float64
#  24  s1__partial_autocorrelation__lag_8                  100 non-null    float64
#  25  s1__partial_autocorrelation__lag_9                  100 non-null    float64
#  26  s1__partial_autocorrelation__lag_7                  100 non-null    float64
#  27  s1__partial_autocorrelation__lag_6                  100 non-null    float64
#  28  s1__number_peaks__n_1                               100 non-null    int64
#  29  s1__number_peaks__n_3                               100 non-null    int64
#  30  s1__number_peaks__n_5                               100 non-null    int64
#  31  s1__number_cwt_peaks__n_1                           100 non-null    int64
#  32  s1__number_peaks__n_10                              100 non-null    int64
#  33  s1__ar_coefficient__coeff_8__k_10                   100 non-null    float64
#  34  s1__partial_autocorrelation__lag_5                  100 non-null    float64
#  35  s1__number_cwt_peaks__n_5                           100 non-null    int64
#  36  s1__spkt_welch_density__coeff_5                     100 non-null    float64
#  37  s1__agg_autocorrelation__f_agg_"median"__maxlag_40  100 non-null    float64
#  38  s1__approximate_entropy__m_2__r_0.5                 100 non-null    float64
#  39  s1__agg_autocorrelation__f_agg_"mean"__maxlag_40    100 non-null    float64
#  40  s1__ar_coefficient__coeff_3__k_10                   100 non-null    float64
#  41  s1__approximate_entropy__m_2__r_0.1                 100 non-null    float64
#  42  s1__lempel_ziv_complexity__bins_3                   100 non-null    float64
#  43  s1__partial_autocorrelation__lag_4                  100 non-null    float64
#  44  s1__fft_coefficient__attr_"abs"__coeff_7            100 non-null    float64
#  45  s1__agg_autocorrelation__f_agg_"var"__maxlag_40     100 non-null    float64
#  46  s1__spkt_welch_density__coeff_2                     100 non-null    float64
#  47  y1                                                  100 non-null    float64
#  48  y2                                                  100 non-null    float64
#  49  y3                                                  100 non-null    float64
# dtypes: float64(42), int64(8)
# memory usage: 39.8+ KB

# %% [markdown]
# ### Extract data

# %%
_X = df.iloc[:, :-3].values
_Y = df.iloc[:, -3:].values
print(_X.shape)
print(_Y.shape)
# Out:
# (100, 47)
# (100, 3)

# %% [markdown]
# ### Initialize DataHandler

# %%
from sklearn.preprocessing import StandardScaler

data_handler = DataHandler(
    _X=_X, _Y=_Y, scalerX=StandardScaler(), scalerY=StandardScaler()
)

# Test
# data_handler.split_and_scale(test_size=0.3, random_state=1)
# X_train, Y_train = data_handler.get_train()
# print(X_train[1,:])

# %% [markdown]
# ### Setup hyper-parameter search

# %% [markdown]
# #### Spliting parameters

# %%
from sklearn.model_selection import ParameterGrid

param_grid_split = [{"random_state": [1, 2, 3, 4, 5], "test_size": [0.3]}]
param_list_split = list(ParameterGrid(param_grid_split))
pp(param_list_split)
# Out:
# [{'random_state': 1, 'test_size': 0.3},
#  {'random_state': 2, 'test_size': 0.3},
#  {'random_state': 3, 'test_size': 0.3},
#  {'random_state': 4, 'test_size': 0.3},
#  {'random_state': 5, 'test_size': 0.3}]

# %% [markdown]
# #### Model hyper parameters

# %%
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.multioutput import MultiOutputRegressor
from sklearn.svm import SVR

base_lr = MultiOutputRegressor(estimator=LinearRegression())
base_svr = MultiOutputRegressor(estimator=SVR())
base_rf = MultiOutputRegressor(estimator=RandomForestRegressor())
# base_gbr = MultiOutputRegressor(estimator=GradientBoostingRegressor())

# This is for testing
reg = RegSwitcher(base=base_lr)
pp(reg.get_params())
# Out:
# {'base__estimator__copy_X': True,
#  'base__estimator__fit_intercept': True,
#  'base__estimator__n_jobs': None,
#  'base__estimator__positive': False,
#  'base__estimator': LinearRegression(),
#  'base__n_jobs': None,
#  'base': MultiOutputRegressor(estimator=LinearRegression())}

# %%
param_grid_hyper = [
    {"base": [base_lr]},
    {"base": [base_svr], "base__estimator__C": [0.01, 0.1, 1]},
    {"base": [base_rf], "base__estimator__n_estimators": [10, 50, 200]},
    # {"base": [base_gbr], "base__estimator__max_depth": [1, 2, 3, 4, 5]},
]

# %%
# Initialize blank model (optional)
reg = RegSwitcher(base=None)


df_arr = []
for idx_split, param_split in enumerate(param_list_split):
    data_handler.split_and_scale(**param_split)
    X_train, Y_train = data_handler.get_train()

    gs = GridSearchCV(
        estimator=reg,
        param_grid=param_grid_hyper,
        cv=3,
        # scoring="neg_mean_squared_error",
        scoring="r2",
        n_jobs=-1,
    )
    gs.fit(X_train, Y_train)
    _df = pd.DataFrame(gs.cv_results_)
    _df["id_split"] = idx_split
    _df["param_split"] = [param_split for _ in range(_df.shape[0])]
    df_arr.append(_df)

df_cv = pd.concat(df_arr)
df_cv = df_cv.reset_index().rename(columns={"index": "id_gs"})

# %%
df_cv
# Out:
#     id_gs  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0       0.009851      0.000658         0.004999        0.001851
# 1       1       0.008899      0.000608         0.005264        0.001055
# 2       2       0.007527      0.001416         0.004180        0.000859
# 3       3       0.009235      0.001442         0.005366        0.000636
# 4       4       0.117810      0.024532         0.010220        0.004322
# 5       5       0.418748      0.031128         0.020074        0.009598
# 6       6       1.232254      0.128623         0.035570        0.004826
# 7       0       0.002334      0.000471         0.000999        0.000001
# 8       1       0.003002      0.001416         0.003177        0.001654
# 9       2       0.005183      0.000946         0.003001        0.000810
# 10      3       0.004852      0.000470         0.001999        0.000817
# 11      4       0.086473      0.004513         0.006035        0.002131
# 12      5       0.316367      0.006586         0.012041        0.000412
# 13      6       1.130839      0.029711         0.036605        0.001986
# 14      0       0.002668      0.000466         0.001000        0.000003
# 15      1       0.002331      0.000475         0.002002        0.000001
# 16      2       0.005845      0.002499         0.003673        0.000946
# 17      3       0.004521      0.000471         0.002663        0.000470
# 18      4       0.072613      0.006700         0.006519        0.002487
# 19      5       0.303466      0.011297         0.011037        0.000004
# 20      6       1.058898      0.028598         0.030645        0.001856
# 21      0       0.003338      0.000478         0.002515        0.001478
# 22      1       0.006195      0.001859         0.003855        0.000957
# 23      2       0.007875      0.000943         0.001848        0.000479
# 24      3       0.005035      0.001092         0.002336        0.000948
# 25      4       0.080868      0.006338         0.005172        0.000245
# 26      5       0.353460      0.021065         0.014723        0.003788
# 27      6       1.045092      0.017767         0.030821        0.002606
# 28      0       0.002665      0.000471         0.002015        0.000814
# 29      1       0.004845      0.002725         0.003507        0.001469
# 30      2       0.008521      0.000820         0.003031        0.001497
# 31      3       0.006710      0.001668         0.002515        0.000405
# 32      4       0.077795      0.015542         0.003681        0.000628
# 33      5       0.358726      0.007506         0.013222        0.001644
# 34      6       1.061874      0.019681         0.030260        0.002295
#
#                                            param_base  \
# 0   MultiOutputRegressor(estimator=LinearRegressio...
# 1               MultiOutputRegressor(estimator=SVR())
# 2               MultiOutputRegressor(estimator=SVR())
# 3               MultiOutputRegressor(estimator=SVR())
# 4   MultiOutputRegressor(estimator=RandomForestReg...
# 5   MultiOutputRegressor(estimator=RandomForestReg...
# 6   MultiOutputRegressor(estimator=RandomForestReg...
# 7   MultiOutputRegressor(estimator=LinearRegressio...
# 8               MultiOutputRegressor(estimator=SVR())
# 9               MultiOutputRegressor(estimator=SVR())
# 10              MultiOutputRegressor(estimator=SVR())
# 11  MultiOutputRegressor(estimator=RandomForestReg...
# 12  MultiOutputRegressor(estimator=RandomForestReg...
# 13  MultiOutputRegressor(estimator=RandomForestReg...
# 14  MultiOutputRegressor(estimator=LinearRegressio...
# 15              MultiOutputRegressor(estimator=SVR())
# 16              MultiOutputRegressor(estimator=SVR())
# 17              MultiOutputRegressor(estimator=SVR())
# 18  MultiOutputRegressor(estimator=RandomForestReg...
# 19  MultiOutputRegressor(estimator=RandomForestReg...
# 20  MultiOutputRegressor(estimator=RandomForestReg...
# 21  MultiOutputRegressor(estimator=LinearRegressio...
# 22              MultiOutputRegressor(estimator=SVR())
# 23              MultiOutputRegressor(estimator=SVR())
# 24              MultiOutputRegressor(estimator=SVR())
# 25  MultiOutputRegressor(estimator=RandomForestReg...
# 26  MultiOutputRegressor(estimator=RandomForestReg...
# 27  MultiOutputRegressor(estimator=RandomForestReg...
# 28  MultiOutputRegressor(estimator=LinearRegressio...
# 29              MultiOutputRegressor(estimator=SVR())
# 30              MultiOutputRegressor(estimator=SVR())
# 31              MultiOutputRegressor(estimator=SVR())
# 32  MultiOutputRegressor(estimator=RandomForestReg...
# 33  MultiOutputRegressor(estimator=RandomForestReg...
# 34  MultiOutputRegressor(estimator=RandomForestReg...
#
#     param_base__estimator__C  param_base__estimator__n_estimators  \
# 0                        NaN                                  NaN
# 1                       0.01                                  NaN
# 2                       0.10                                  NaN
# 3                       1.00                                  NaN
# 4                        NaN                                 10.0
# 5                        NaN                                 50.0
# 6                        NaN                                200.0
# 7                        NaN                                  NaN
# 8                       0.01                                  NaN
# 9                       0.10                                  NaN
# 10                      1.00                                  NaN
# 11                       NaN                                 10.0
# 12                       NaN                                 50.0
# 13                       NaN                                200.0
# 14                       NaN                                  NaN
# 15                      0.01                                  NaN
# 16                      0.10                                  NaN
# 17                      1.00                                  NaN
# 18                       NaN                                 10.0
# 19                       NaN                                 50.0
# 20                       NaN                                200.0
# 21                       NaN                                  NaN
# 22                      0.01                                  NaN
# 23                      0.10                                  NaN
# 24                      1.00                                  NaN
# 25                       NaN                                 10.0
# 26                       NaN                                 50.0
# 27                       NaN                                200.0
# 28                       NaN                                  NaN
# 29                      0.01                                  NaN
# 30                      0.10                                  NaN
# 31                      1.00                                  NaN
# 32                       NaN                                 10.0
# 33                       NaN                                 50.0
# 34                       NaN                                200.0
#
#                                                params  split0_test_score  \
# 0   {'base': MultiOutputRegressor(estimator=Linear...           0.038175
# 1   {'base': MultiOutputRegressor(estimator=SVR())...          -0.002276
# 2   {'base': MultiOutputRegressor(estimator=SVR())...           0.302295
# 3   {'base': MultiOutputRegressor(estimator=SVR())...           0.617707
# 4   {'base': MultiOutputRegressor(estimator=Random...           0.683638
# 5   {'base': MultiOutputRegressor(estimator=Random...           0.744007
# 6   {'base': MultiOutputRegressor(estimator=Random...           0.727435
# 7   {'base': MultiOutputRegressor(estimator=Linear...          -0.139373
# 8   {'base': MultiOutputRegressor(estimator=SVR())...           0.042289
# 9   {'base': MultiOutputRegressor(estimator=SVR())...           0.328093
# 10  {'base': MultiOutputRegressor(estimator=SVR())...           0.711780
# 11  {'base': MultiOutputRegressor(estimator=Random...           0.640540
# 12  {'base': MultiOutputRegressor(estimator=Random...           0.636217
# 13  {'base': MultiOutputRegressor(estimator=Random...           0.612274
# 14  {'base': MultiOutputRegressor(estimator=Linear...          -0.947499
# 15  {'base': MultiOutputRegressor(estimator=SVR())...           0.019576
# 16  {'base': MultiOutputRegressor(estimator=SVR())...           0.283878
# 17  {'base': MultiOutputRegressor(estimator=SVR())...           0.761287
# 18  {'base': MultiOutputRegressor(estimator=Random...           0.764044
# 19  {'base': MultiOutputRegressor(estimator=Random...           0.756100
# 20  {'base': MultiOutputRegressor(estimator=Random...           0.759526
# 21  {'base': MultiOutputRegressor(estimator=Linear...         -14.821435
# 22  {'base': MultiOutputRegressor(estimator=SVR())...           0.012710
# 23  {'base': MultiOutputRegressor(estimator=SVR())...           0.265889
# 24  {'base': MultiOutputRegressor(estimator=SVR())...           0.717487
# 25  {'base': MultiOutputRegressor(estimator=Random...           0.769611
# 26  {'base': MultiOutputRegressor(estimator=Random...           0.782078
# 27  {'base': MultiOutputRegressor(estimator=Random...           0.786911
# 28  {'base': MultiOutputRegressor(estimator=Linear...           0.702550
# 29  {'base': MultiOutputRegressor(estimator=SVR())...          -0.058129
# 30  {'base': MultiOutputRegressor(estimator=SVR())...           0.170822
# 31  {'base': MultiOutputRegressor(estimator=SVR())...           0.643669
# 32  {'base': MultiOutputRegressor(estimator=Random...           0.606331
# 33  {'base': MultiOutputRegressor(estimator=Random...           0.719926
# 34  {'base': MultiOutputRegressor(estimator=Random...           0.722925
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.752024          -7.906865        -2.372222        3.924419
# 1           -0.041889           0.024655        -0.006503        0.027330
# 2            0.309570           0.302825         0.304896        0.003312
# 3            0.814445           0.800537         0.744229        0.089645
# 4            0.800187           0.759337         0.747721        0.048285
# 5            0.859561           0.711459         0.771676        0.063549
# 6            0.851899           0.713705         0.764347        0.062162
# 7            0.777359          -6.449578        -1.937197        3.212609
# 8            0.032906          -0.041063         0.011377        0.037278
# 9            0.341163           0.244914         0.304724        0.042627
# 10           0.759918           0.637827         0.703175        0.050213
# 11           0.803752           0.779732         0.741341        0.071949
# 12           0.833272           0.786348         0.751946        0.084045
# 13           0.841456           0.779673         0.744468        0.096818
# 14           0.714162         -18.053966        -6.095767        8.482891
# 15          -0.308430           0.048673        -0.080060        0.161918
# 16           0.197325           0.308814         0.263339        0.047776
# 17           0.802721           0.695178         0.753062        0.044288
# 18           0.625404           0.798574         0.729341        0.074834
# 19           0.644609           0.799184         0.733297        0.065132
# 20           0.687138           0.806579         0.751081        0.049126
# 21           0.932135           0.686950        -4.400783        7.369193
# 22           0.009834           0.022086         0.014877        0.005231
# 23           0.353549           0.301394         0.306944        0.036002
# 24           0.852824           0.769057         0.779790        0.055770
# 25           0.728842           0.638335         0.712263        0.054860
# 26           0.760094           0.701898         0.748023        0.033828
# 27           0.732379           0.686272         0.735187        0.041133
# 28          -1.052360         -10.808093        -3.719301        5.063474
# 29          -0.051819          -0.172688        -0.094212        0.055550
# 30           0.271130           0.137605         0.193186        0.056759
# 31           0.653212           0.646915         0.647932        0.003962
# 32           0.696913           0.713734         0.672326        0.047168
# 33           0.711759           0.735046         0.722244        0.009647
# 34           0.740524           0.744820         0.736090        0.009473
#
#     rank_test_score  id_split                            param_split
# 0                 7         0  {'random_state': 1, 'test_size': 0.3}
# 1                 6         0  {'random_state': 1, 'test_size': 0.3}
# 2                 5         0  {'random_state': 1, 'test_size': 0.3}
# 3                 4         0  {'random_state': 1, 'test_size': 0.3}
# 4                 3         0  {'random_state': 1, 'test_size': 0.3}
# 5                 1         0  {'random_state': 1, 'test_size': 0.3}
# 6                 2         0  {'random_state': 1, 'test_size': 0.3}
# 7                 7         1  {'random_state': 2, 'test_size': 0.3}
# 8                 6         1  {'random_state': 2, 'test_size': 0.3}
# 9                 5         1  {'random_state': 2, 'test_size': 0.3}
# 10                4         1  {'random_state': 2, 'test_size': 0.3}
# 11                3         1  {'random_state': 2, 'test_size': 0.3}
# 12                1         1  {'random_state': 2, 'test_size': 0.3}
# 13                2         1  {'random_state': 2, 'test_size': 0.3}
# 14                7         2  {'random_state': 3, 'test_size': 0.3}
# 15                6         2  {'random_state': 3, 'test_size': 0.3}
# 16                5         2  {'random_state': 3, 'test_size': 0.3}
# 17                1         2  {'random_state': 3, 'test_size': 0.3}
# 18                4         2  {'random_state': 3, 'test_size': 0.3}
# 19                3         2  {'random_state': 3, 'test_size': 0.3}
# 20                2         2  {'random_state': 3, 'test_size': 0.3}
# 21                7         3  {'random_state': 4, 'test_size': 0.3}
# 22                6         3  {'random_state': 4, 'test_size': 0.3}
# 23                5         3  {'random_state': 4, 'test_size': 0.3}
# 24                1         3  {'random_state': 4, 'test_size': 0.3}
# 25                4         3  {'random_state': 4, 'test_size': 0.3}
# 26                2         3  {'random_state': 4, 'test_size': 0.3}
# 27                3         3  {'random_state': 4, 'test_size': 0.3}
# 28                7         4  {'random_state': 5, 'test_size': 0.3}
# 29                6         4  {'random_state': 5, 'test_size': 0.3}
# 30                5         4  {'random_state': 5, 'test_size': 0.3}
# 31                4         4  {'random_state': 5, 'test_size': 0.3}
# 32                3         4  {'random_state': 5, 'test_size': 0.3}
# 33                2         4  {'random_state': 5, 'test_size': 0.3}
# 34                1         4  {'random_state': 5, 'test_size': 0.3}

# %%
# Create a new column called `"estimator"` that contains the class name (as a string) of the estimator used in each row.
# 1. **The DataFrame (`df_fit`):**
#    - Each row represents a different set of hyperparameters tested during grid search.
#    - The `"param_base"` column contains objects `MultiOutputRegressor`.
# 2. **The `.apply()` Method:**
#    - `df_fit["param_base"].apply(...)` applies a function to every entry in the `"param_base"` column.
# 3. **The Lambda Function:**
#    - For each entry `x` in `"param_base"`, the lambda function does:
#      - `x.estimator`: Accesses the estimator object.
#      - `x.estimator.__class__`: Gets the class of the estimator.
#      - `x.estimator.__class__.__name__`: Gets the name of the class as a string (e.g., `"RandomForestClassifier"`).
# 4. **Assigning the Result:**
#    - The resulting estimator names are stored in a new column `"estimator"`.

df_cv["estimator"] = df_cv["param_base"].apply(lambda x: x.estimator.__class__.__name__)

# Test
# pp(df_eval["param_base"][0].estimator.__class__.__name__)

# %%
df_cv
# Out:
#     id_gs  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0       0.009851      0.000658         0.004999        0.001851
# 1       1       0.008899      0.000608         0.005264        0.001055
# 2       2       0.007527      0.001416         0.004180        0.000859
# 3       3       0.009235      0.001442         0.005366        0.000636
# 4       4       0.117810      0.024532         0.010220        0.004322
# 5       5       0.418748      0.031128         0.020074        0.009598
# 6       6       1.232254      0.128623         0.035570        0.004826
# 7       0       0.002334      0.000471         0.000999        0.000001
# 8       1       0.003002      0.001416         0.003177        0.001654
# 9       2       0.005183      0.000946         0.003001        0.000810
# 10      3       0.004852      0.000470         0.001999        0.000817
# 11      4       0.086473      0.004513         0.006035        0.002131
# 12      5       0.316367      0.006586         0.012041        0.000412
# 13      6       1.130839      0.029711         0.036605        0.001986
# 14      0       0.002668      0.000466         0.001000        0.000003
# 15      1       0.002331      0.000475         0.002002        0.000001
# 16      2       0.005845      0.002499         0.003673        0.000946
# 17      3       0.004521      0.000471         0.002663        0.000470
# 18      4       0.072613      0.006700         0.006519        0.002487
# 19      5       0.303466      0.011297         0.011037        0.000004
# 20      6       1.058898      0.028598         0.030645        0.001856
# 21      0       0.003338      0.000478         0.002515        0.001478
# 22      1       0.006195      0.001859         0.003855        0.000957
# 23      2       0.007875      0.000943         0.001848        0.000479
# 24      3       0.005035      0.001092         0.002336        0.000948
# 25      4       0.080868      0.006338         0.005172        0.000245
# 26      5       0.353460      0.021065         0.014723        0.003788
# 27      6       1.045092      0.017767         0.030821        0.002606
# 28      0       0.002665      0.000471         0.002015        0.000814
# 29      1       0.004845      0.002725         0.003507        0.001469
# 30      2       0.008521      0.000820         0.003031        0.001497
# 31      3       0.006710      0.001668         0.002515        0.000405
# 32      4       0.077795      0.015542         0.003681        0.000628
# 33      5       0.358726      0.007506         0.013222        0.001644
# 34      6       1.061874      0.019681         0.030260        0.002295
#
#                                            param_base  \
# 0   MultiOutputRegressor(estimator=LinearRegressio...
# 1               MultiOutputRegressor(estimator=SVR())
# 2               MultiOutputRegressor(estimator=SVR())
# 3               MultiOutputRegressor(estimator=SVR())
# 4   MultiOutputRegressor(estimator=RandomForestReg...
# 5   MultiOutputRegressor(estimator=RandomForestReg...
# 6   MultiOutputRegressor(estimator=RandomForestReg...
# 7   MultiOutputRegressor(estimator=LinearRegressio...
# 8               MultiOutputRegressor(estimator=SVR())
# 9               MultiOutputRegressor(estimator=SVR())
# 10              MultiOutputRegressor(estimator=SVR())
# 11  MultiOutputRegressor(estimator=RandomForestReg...
# 12  MultiOutputRegressor(estimator=RandomForestReg...
# 13  MultiOutputRegressor(estimator=RandomForestReg...
# 14  MultiOutputRegressor(estimator=LinearRegressio...
# 15              MultiOutputRegressor(estimator=SVR())
# 16              MultiOutputRegressor(estimator=SVR())
# 17              MultiOutputRegressor(estimator=SVR())
# 18  MultiOutputRegressor(estimator=RandomForestReg...
# 19  MultiOutputRegressor(estimator=RandomForestReg...
# 20  MultiOutputRegressor(estimator=RandomForestReg...
# 21  MultiOutputRegressor(estimator=LinearRegressio...
# 22              MultiOutputRegressor(estimator=SVR())
# 23              MultiOutputRegressor(estimator=SVR())
# 24              MultiOutputRegressor(estimator=SVR())
# 25  MultiOutputRegressor(estimator=RandomForestReg...
# 26  MultiOutputRegressor(estimator=RandomForestReg...
# 27  MultiOutputRegressor(estimator=RandomForestReg...
# 28  MultiOutputRegressor(estimator=LinearRegressio...
# 29              MultiOutputRegressor(estimator=SVR())
# 30              MultiOutputRegressor(estimator=SVR())
# 31              MultiOutputRegressor(estimator=SVR())
# 32  MultiOutputRegressor(estimator=RandomForestReg...
# 33  MultiOutputRegressor(estimator=RandomForestReg...
# 34  MultiOutputRegressor(estimator=RandomForestReg...
#
#     param_base__estimator__C  param_base__estimator__n_estimators  \
# 0                        NaN                                  NaN
# 1                       0.01                                  NaN
# 2                       0.10                                  NaN
# 3                       1.00                                  NaN
# 4                        NaN                                 10.0
# 5                        NaN                                 50.0
# 6                        NaN                                200.0
# 7                        NaN                                  NaN
# 8                       0.01                                  NaN
# 9                       0.10                                  NaN
# 10                      1.00                                  NaN
# 11                       NaN                                 10.0
# 12                       NaN                                 50.0
# 13                       NaN                                200.0
# 14                       NaN                                  NaN
# 15                      0.01                                  NaN
# 16                      0.10                                  NaN
# 17                      1.00                                  NaN
# 18                       NaN                                 10.0
# 19                       NaN                                 50.0
# 20                       NaN                                200.0
# 21                       NaN                                  NaN
# 22                      0.01                                  NaN
# 23                      0.10                                  NaN
# 24                      1.00                                  NaN
# 25                       NaN                                 10.0
# 26                       NaN                                 50.0
# 27                       NaN                                200.0
# 28                       NaN                                  NaN
# 29                      0.01                                  NaN
# 30                      0.10                                  NaN
# 31                      1.00                                  NaN
# 32                       NaN                                 10.0
# 33                       NaN                                 50.0
# 34                       NaN                                200.0
#
#                                                params  split0_test_score  \
# 0   {'base': MultiOutputRegressor(estimator=Linear...           0.038175
# 1   {'base': MultiOutputRegressor(estimator=SVR())...          -0.002276
# 2   {'base': MultiOutputRegressor(estimator=SVR())...           0.302295
# 3   {'base': MultiOutputRegressor(estimator=SVR())...           0.617707
# 4   {'base': MultiOutputRegressor(estimator=Random...           0.683638
# 5   {'base': MultiOutputRegressor(estimator=Random...           0.744007
# 6   {'base': MultiOutputRegressor(estimator=Random...           0.727435
# 7   {'base': MultiOutputRegressor(estimator=Linear...          -0.139373
# 8   {'base': MultiOutputRegressor(estimator=SVR())...           0.042289
# 9   {'base': MultiOutputRegressor(estimator=SVR())...           0.328093
# 10  {'base': MultiOutputRegressor(estimator=SVR())...           0.711780
# 11  {'base': MultiOutputRegressor(estimator=Random...           0.640540
# 12  {'base': MultiOutputRegressor(estimator=Random...           0.636217
# 13  {'base': MultiOutputRegressor(estimator=Random...           0.612274
# 14  {'base': MultiOutputRegressor(estimator=Linear...          -0.947499
# 15  {'base': MultiOutputRegressor(estimator=SVR())...           0.019576
# 16  {'base': MultiOutputRegressor(estimator=SVR())...           0.283878
# 17  {'base': MultiOutputRegressor(estimator=SVR())...           0.761287
# 18  {'base': MultiOutputRegressor(estimator=Random...           0.764044
# 19  {'base': MultiOutputRegressor(estimator=Random...           0.756100
# 20  {'base': MultiOutputRegressor(estimator=Random...           0.759526
# 21  {'base': MultiOutputRegressor(estimator=Linear...         -14.821435
# 22  {'base': MultiOutputRegressor(estimator=SVR())...           0.012710
# 23  {'base': MultiOutputRegressor(estimator=SVR())...           0.265889
# 24  {'base': MultiOutputRegressor(estimator=SVR())...           0.717487
# 25  {'base': MultiOutputRegressor(estimator=Random...           0.769611
# 26  {'base': MultiOutputRegressor(estimator=Random...           0.782078
# 27  {'base': MultiOutputRegressor(estimator=Random...           0.786911
# 28  {'base': MultiOutputRegressor(estimator=Linear...           0.702550
# 29  {'base': MultiOutputRegressor(estimator=SVR())...          -0.058129
# 30  {'base': MultiOutputRegressor(estimator=SVR())...           0.170822
# 31  {'base': MultiOutputRegressor(estimator=SVR())...           0.643669
# 32  {'base': MultiOutputRegressor(estimator=Random...           0.606331
# 33  {'base': MultiOutputRegressor(estimator=Random...           0.719926
# 34  {'base': MultiOutputRegressor(estimator=Random...           0.722925
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.752024          -7.906865        -2.372222        3.924419
# 1           -0.041889           0.024655        -0.006503        0.027330
# 2            0.309570           0.302825         0.304896        0.003312
# 3            0.814445           0.800537         0.744229        0.089645
# 4            0.800187           0.759337         0.747721        0.048285
# 5            0.859561           0.711459         0.771676        0.063549
# 6            0.851899           0.713705         0.764347        0.062162
# 7            0.777359          -6.449578        -1.937197        3.212609
# 8            0.032906          -0.041063         0.011377        0.037278
# 9            0.341163           0.244914         0.304724        0.042627
# 10           0.759918           0.637827         0.703175        0.050213
# 11           0.803752           0.779732         0.741341        0.071949
# 12           0.833272           0.786348         0.751946        0.084045
# 13           0.841456           0.779673         0.744468        0.096818
# 14           0.714162         -18.053966        -6.095767        8.482891
# 15          -0.308430           0.048673        -0.080060        0.161918
# 16           0.197325           0.308814         0.263339        0.047776
# 17           0.802721           0.695178         0.753062        0.044288
# 18           0.625404           0.798574         0.729341        0.074834
# 19           0.644609           0.799184         0.733297        0.065132
# 20           0.687138           0.806579         0.751081        0.049126
# 21           0.932135           0.686950        -4.400783        7.369193
# 22           0.009834           0.022086         0.014877        0.005231
# 23           0.353549           0.301394         0.306944        0.036002
# 24           0.852824           0.769057         0.779790        0.055770
# 25           0.728842           0.638335         0.712263        0.054860
# 26           0.760094           0.701898         0.748023        0.033828
# 27           0.732379           0.686272         0.735187        0.041133
# 28          -1.052360         -10.808093        -3.719301        5.063474
# 29          -0.051819          -0.172688        -0.094212        0.055550
# 30           0.271130           0.137605         0.193186        0.056759
# 31           0.653212           0.646915         0.647932        0.003962
# 32           0.696913           0.713734         0.672326        0.047168
# 33           0.711759           0.735046         0.722244        0.009647
# 34           0.740524           0.744820         0.736090        0.009473
#
#     rank_test_score  id_split                            param_split  \
# 0                 7         0  {'random_state': 1, 'test_size': 0.3}
# 1                 6         0  {'random_state': 1, 'test_size': 0.3}
# 2                 5         0  {'random_state': 1, 'test_size': 0.3}
# 3                 4         0  {'random_state': 1, 'test_size': 0.3}
# 4                 3         0  {'random_state': 1, 'test_size': 0.3}
# 5                 1         0  {'random_state': 1, 'test_size': 0.3}
# 6                 2         0  {'random_state': 1, 'test_size': 0.3}
# 7                 7         1  {'random_state': 2, 'test_size': 0.3}
# 8                 6         1  {'random_state': 2, 'test_size': 0.3}
# 9                 5         1  {'random_state': 2, 'test_size': 0.3}
# 10                4         1  {'random_state': 2, 'test_size': 0.3}
# 11                3         1  {'random_state': 2, 'test_size': 0.3}
# 12                1         1  {'random_state': 2, 'test_size': 0.3}
# 13                2         1  {'random_state': 2, 'test_size': 0.3}
# 14                7         2  {'random_state': 3, 'test_size': 0.3}
# 15                6         2  {'random_state': 3, 'test_size': 0.3}
# 16                5         2  {'random_state': 3, 'test_size': 0.3}
# 17                1         2  {'random_state': 3, 'test_size': 0.3}
# 18                4         2  {'random_state': 3, 'test_size': 0.3}
# 19                3         2  {'random_state': 3, 'test_size': 0.3}
# 20                2         2  {'random_state': 3, 'test_size': 0.3}
# 21                7         3  {'random_state': 4, 'test_size': 0.3}
# 22                6         3  {'random_state': 4, 'test_size': 0.3}
# 23                5         3  {'random_state': 4, 'test_size': 0.3}
# 24                1         3  {'random_state': 4, 'test_size': 0.3}
# 25                4         3  {'random_state': 4, 'test_size': 0.3}
# 26                2         3  {'random_state': 4, 'test_size': 0.3}
# 27                3         3  {'random_state': 4, 'test_size': 0.3}
# 28                7         4  {'random_state': 5, 'test_size': 0.3}
# 29                6         4  {'random_state': 5, 'test_size': 0.3}
# 30                5         4  {'random_state': 5, 'test_size': 0.3}
# 31                4         4  {'random_state': 5, 'test_size': 0.3}
# 32                3         4  {'random_state': 5, 'test_size': 0.3}
# 33                2         4  {'random_state': 5, 'test_size': 0.3}
# 34                1         4  {'random_state': 5, 'test_size': 0.3}
#
#                 estimator
# 0        LinearRegression
# 1                     SVR
# 2                     SVR
# 3                     SVR
# 4   RandomForestRegressor
# 5   RandomForestRegressor
# 6   RandomForestRegressor
# 7        LinearRegression
# 8                     SVR
# 9                     SVR
# 10                    SVR
# 11  RandomForestRegressor
# 12  RandomForestRegressor
# 13  RandomForestRegressor
# 14       LinearRegression
# 15                    SVR
# 16                    SVR
# 17                    SVR
# 18  RandomForestRegressor
# 19  RandomForestRegressor
# 20  RandomForestRegressor
# 21       LinearRegression
# 22                    SVR
# 23                    SVR
# 24                    SVR
# 25  RandomForestRegressor
# 26  RandomForestRegressor
# 27  RandomForestRegressor
# 28       LinearRegression
# 29                    SVR
# 30                    SVR
# 31                    SVR
# 32  RandomForestRegressor
# 33  RandomForestRegressor
# 34  RandomForestRegressor

# %%
# This imports Python’s built-in regular expression module, which is used for pattern matching in strings.
import re

# - This regex pattern matches column names like `split0_test_score`, `split1_test_score`, etc.
#     - `split` - literal string
#     - `\d+` - one or more digits
#     - `_test_score` - literal string
pattern = r"split\d+_test_score"

# - Iterates through all column names in `df_fit`
# - Selects columns whose names match the pattern exactly
# - **Result:** `colsSplitTestScore` is a list of all columns like `split0_test_score`, `split1_test_score`, etc.
colsSplitTestScore = [col for col in df_cv.columns if re.fullmatch(pattern, col)]

# - Selects all the split test score columns from `df_fit`
# - For each row, collects the values from these columns into a NumPy array
# - Assigns this array to a new column called `validation_scores`
# - **Result:** Each row in `validation_scores` contains an array of validation scores across all splits for that parameter set
df_cv["validation_scores"] = df_cv[colsSplitTestScore].apply(
    lambda row: row.values, axis=1
)

# %%
# Extract only columns that I will use
pp(df_cv.columns)

pattern = r"split\d+_test_score"
colsSplitTestScore = [col for col in df_cv.columns if re.fullmatch(pattern, col)]
pp(colsSplitTestScore)


cols = [
    "id_split",
    "param_split",
    "id_gs",
    "params",
    "estimator",
    "mean_test_score",
    "std_test_score",
    "rank_test_score",
    "validation_scores",
]

df_cv = df_cv[cols]
df_cv
# Out:
# Index(['id_gs', 'mean_fit_time', 'std_fit_time', 'mean_score_time',
#        'std_score_time', 'param_base', 'param_base__estimator__C',
#        'param_base__estimator__n_estimators', 'params', 'split0_test_score',
#        'split1_test_score', 'split2_test_score', 'mean_test_score',
#        'std_test_score', 'rank_test_score', 'id_split', 'param_split',
#        'estimator', 'validation_scores'],
#       dtype='object')
# ['split0_test_score', 'split1_test_score', 'split2_test_score']
#     id_split                            param_split  id_gs  \
# 0          0  {'random_state': 1, 'test_size': 0.3}      0
# 1          0  {'random_state': 1, 'test_size': 0.3}      1
# 2          0  {'random_state': 1, 'test_size': 0.3}      2
# 3          0  {'random_state': 1, 'test_size': 0.3}      3
# 4          0  {'random_state': 1, 'test_size': 0.3}      4
# 5          0  {'random_state': 1, 'test_size': 0.3}      5
# 6          0  {'random_state': 1, 'test_size': 0.3}      6
# 7          1  {'random_state': 2, 'test_size': 0.3}      0
# 8          1  {'random_state': 2, 'test_size': 0.3}      1
# 9          1  {'random_state': 2, 'test_size': 0.3}      2
# 10         1  {'random_state': 2, 'test_size': 0.3}      3
# 11         1  {'random_state': 2, 'test_size': 0.3}      4
# 12         1  {'random_state': 2, 'test_size': 0.3}      5
# 13         1  {'random_state': 2, 'test_size': 0.3}      6
# 14         2  {'random_state': 3, 'test_size': 0.3}      0
# 15         2  {'random_state': 3, 'test_size': 0.3}      1
# 16         2  {'random_state': 3, 'test_size': 0.3}      2
# 17         2  {'random_state': 3, 'test_size': 0.3}      3
# 18         2  {'random_state': 3, 'test_size': 0.3}      4
# 19         2  {'random_state': 3, 'test_size': 0.3}      5
# 20         2  {'random_state': 3, 'test_size': 0.3}      6
# 21         3  {'random_state': 4, 'test_size': 0.3}      0
# 22         3  {'random_state': 4, 'test_size': 0.3}      1
# 23         3  {'random_state': 4, 'test_size': 0.3}      2
# 24         3  {'random_state': 4, 'test_size': 0.3}      3
# 25         3  {'random_state': 4, 'test_size': 0.3}      4
# 26         3  {'random_state': 4, 'test_size': 0.3}      5
# 27         3  {'random_state': 4, 'test_size': 0.3}      6
# 28         4  {'random_state': 5, 'test_size': 0.3}      0
# 29         4  {'random_state': 5, 'test_size': 0.3}      1
# 30         4  {'random_state': 5, 'test_size': 0.3}      2
# 31         4  {'random_state': 5, 'test_size': 0.3}      3
# 32         4  {'random_state': 5, 'test_size': 0.3}      4
# 33         4  {'random_state': 5, 'test_size': 0.3}      5
# 34         4  {'random_state': 5, 'test_size': 0.3}      6
#
#                                                params              estimator  \
# 0   {'base': MultiOutputRegressor(estimator=Linear...       LinearRegression
# 1   {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 2   {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 3   {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 4   {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 5   {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 6   {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 7   {'base': MultiOutputRegressor(estimator=Linear...       LinearRegression
# 8   {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 9   {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 10  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 11  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 12  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 13  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 14  {'base': MultiOutputRegressor(estimator=Linear...       LinearRegression
# 15  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 16  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 17  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 18  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 19  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 20  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 21  {'base': MultiOutputRegressor(estimator=Linear...       LinearRegression
# 22  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 23  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 24  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 25  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 26  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 27  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 28  {'base': MultiOutputRegressor(estimator=Linear...       LinearRegression
# 29  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 30  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 31  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
# 32  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 33  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
# 34  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#
#     mean_test_score  std_test_score  rank_test_score  \
# 0         -2.372222        3.924419                7
# 1         -0.006503        0.027330                6
# 2          0.304896        0.003312                5
# 3          0.744229        0.089645                4
# 4          0.747721        0.048285                3
# 5          0.771676        0.063549                1
# 6          0.764347        0.062162                2
# 7         -1.937197        3.212609                7
# 8          0.011377        0.037278                6
# 9          0.304724        0.042627                5
# 10         0.703175        0.050213                4
# 11         0.741341        0.071949                3
# 12         0.751946        0.084045                1
# 13         0.744468        0.096818                2
# 14        -6.095767        8.482891                7
# 15        -0.080060        0.161918                6
# 16         0.263339        0.047776                5
# 17         0.753062        0.044288                1
# 18         0.729341        0.074834                4
# 19         0.733297        0.065132                3
# 20         0.751081        0.049126                2
# 21        -4.400783        7.369193                7
# 22         0.014877        0.005231                6
# 23         0.306944        0.036002                5
# 24         0.779790        0.055770                1
# 25         0.712263        0.054860                4
# 26         0.748023        0.033828                2
# 27         0.735187        0.041133                3
# 28        -3.719301        5.063474                7
# 29        -0.094212        0.055550                6
# 30         0.193186        0.056759                5
# 31         0.647932        0.003962                4
# 32         0.672326        0.047168                3
# 33         0.722244        0.009647                2
# 34         0.736090        0.009473                1
#
#                                     validation_scores
# 0   [0.0381745359446262, 0.7520240440765592, -7.90...
# 1   [-0.0022755109373579683, -0.04188876497945082,...
# 2   [0.302294515805052, 0.3095696294549572, 0.3028...
# 3   [0.6177065038720949, 0.8144446900525925, 0.800...
# 4   [0.6836383212083342, 0.8001871180210897, 0.759...
# 5   [0.7440071033135265, 0.8595609368051339, 0.711...
# 6   [0.7274352141712331, 0.8518994316637137, 0.713...
# 7   [-0.13937271441371277, 0.777359375151465, -6.4...
# 8   [0.042289212343515126, 0.032905918683216906, -...
# 9   [0.3280930724834618, 0.3411633989478616, 0.244...
# 10  [0.7117799983754173, 0.7599177723301004, 0.637...
# 11  [0.6405395989927651, 0.8037522034479799, 0.779...
# 12  [0.6362171577328025, 0.8332717475590569, 0.786...
# 13  [0.6122743774417579, 0.8414562346432266, 0.779...
# 14  [-0.947498514280532, 0.7141621891195524, -18.0...
# 15  [0.019575866397430104, -0.30843027353755464, 0...
# 16  [0.2838778689134469, 0.1973245470954702, 0.308...
# 17  [0.7612869455812917, 0.8027208605802253, 0.695...
# 18  [0.764043971312375, 0.6254044361244769, 0.7985...
# 19  [0.7560995394315996, 0.6446088373597528, 0.799...
# 20  [0.7595257195190724, 0.6871382253825863, 0.806...
# 21  [-14.821434516944576, 0.9321352673466916, 0.68...
# 22  [0.012710443902856916, 0.009834211215422347, 0...
# 23  [0.2658891154205591, 0.3535490255015444, 0.301...
# 24  [0.7174872511019424, 0.8528239585634415, 0.769...
# 25  [0.7696107378512521, 0.7288424934570745, 0.638...
# 26  [0.7820779837104587, 0.7600940007498824, 0.701...
# 27  [0.7869107174313729, 0.7323790249063794, 0.686...
# 28  [0.7025502758354495, -1.0523604642979272, -10....
# 29  [-0.05812927528668669, -0.051819192572520135, ...
# 30  [0.17082160924434067, 0.2711300171135891, 0.13...
# 31  [0.6436690352077227, 0.6532119783653022, 0.646...
# 32  [0.6063310987539144, 0.6969134306584666, 0.713...
# 33  [0.7199257677571617, 0.7117592339647992, 0.735...
# 34  [0.7229252151628008, 0.7405239313410844, 0.744...

# %% [markdown]
# ### Save data

# %%
if SAVE_DATA:
    filename = f"S04_data_{dt}.pkl"

    data_save = {
        "desc": "This is the saved data",
        "data_handler": data_handler,
        "param_split": param_split,
        "param_grid_hyper": param_grid_hyper,
        "df_cv": df_cv,
    }

    # Save the model
    MyUtil.save_data(filename=filename, data=data_save)

# %% [markdown]
# ### Test loading data

# %%
if SAVE_DATA:
    data_load = MyUtil.load_data(filename=filename)

    pp(list(data_load.keys()))
