# %%
import pandas as pd
import optuna

# %%
from sklearn.datasets import load_diabetes

dataset = load_diabetes()
_X = dataset.data
_y = dataset.target
print(_X.shape, _y.shape)
# Out:
# (442, 10) (442,)

# %%
from sklearn.model_selection import train_test_split

_X_train, _X_test, _y_train, _y_test = train_test_split(
    _X, _y, test_size=0.3, random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler

scX = StandardScaler()
_X_train = scX.fit_transform(_X_train)
_X_test = scX.transform(_X_test)

scY = StandardScaler()
_y_train = scY.fit_transform(_y_train.reshape(-1, 1)).flatten()
_y_test = scY.transform(_y_test.reshape(-1, 1)).flatten()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

def objective(trial: optuna.trial.Trial):

    n_estimators = trial.suggest_int("n_estimators", 20, 200)
    max_depth = trial.suggest_int("max_depth", 2, 32, log=True)
    forrest = RandomForestRegressor(n_estimators=n_estimators, max_depth=max_depth)

    scores = cross_val_score(forrest, _X_train, _y_train, cv=3, scoring="neg_mean_squared_error")
    return -scores.mean()

# %%
study = optuna.create_study()
# Out:
# [I 2025-12-25 11:04:20,162] A new study created in memory with name: no-name-6239ef7b-4cd5-43e1-b976-7be851123507

# %%
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-12-25 11:05:35,128] Trial 50 finished with value: 0.5730606422386085 and parameters: {'n_estimators': 146, 'max_depth': 3}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:36,095] Trial 51 finished with value: 0.5817204410519233 and parameters: {'n_estimators': 193, 'max_depth': 6}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:37,073] Trial 52 finished with value: 0.5817879726962252 and parameters: {'n_estimators': 180, 'max_depth': 11}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:37,994] Trial 53 finished with value: 0.5837761407214794 and parameters: {'n_estimators': 193, 'max_depth': 7}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:38,933] Trial 54 finished with value: 0.5846690917402008 and parameters: {'n_estimators': 189, 'max_depth': 8}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:39,675] Trial 55 finished with value: 0.5693201711532113 and parameters: {'n_estimators': 200, 'max_depth': 4}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:40,601] Trial 56 finished with value: 0.5775385139651877 and parameters: {'n_estimators': 174, 'max_depth': 10}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:41,287] Trial 57 finished with value: 0.5740691800002412 and parameters: {'n_estimators': 167, 'max_depth': 5}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:41,640] Trial 58 finished with value: 0.5753724117182194 and parameters: {'n_estimators': 77, 'max_depth': 6}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:42,054] Trial 59 finished with value: 0.571090306149273 and parameters: {'n_estimators': 119, 'max_depth': 3}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:42,760] Trial 60 finished with value: 0.568258908162699 and parameters: {'n_estimators': 192, 'max_depth': 4}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:43,476] Trial 61 finished with value: 0.5727721272876772 and parameters: {'n_estimators': 192, 'max_depth': 4}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:44,226] Trial 62 finished with value: 0.577180065612192 and parameters: {'n_estimators': 181, 'max_depth': 5}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:45,082] Trial 63 finished with value: 0.5808445965586557 and parameters: {'n_estimators': 195, 'max_depth': 6}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:45,210] Trial 64 finished with value: 0.582879156271996 and parameters: {'n_estimators': 29, 'max_depth': 4}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:45,638] Trial 65 finished with value: 0.5792242286565153 and parameters: {'n_estimators': 103, 'max_depth': 5}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:46,258] Trial 66 finished with value: 0.5712908286680296 and parameters: {'n_estimators': 186, 'max_depth': 3}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:47,172] Trial 67 finished with value: 0.5903718920126636 and parameters: {'n_estimators': 171, 'max_depth': 21}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:47,625] Trial 68 finished with value: 0.573137450207908 and parameters: {'n_estimators': 90, 'max_depth': 7}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:47,803] Trial 69 finished with value: 0.5687810358587697 and parameters: {'n_estimators': 47, 'max_depth': 3}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:48,781] Trial 70 finished with value: 0.5826143021095077 and parameters: {'n_estimators': 177, 'max_depth': 8}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:48,874] Trial 71 finished with value: 0.5940548296105853 and parameters: {'n_estimators': 20, 'max_depth': 4}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:48,995] Trial 72 finished with value: 0.5865965843560069 and parameters: {'n_estimators': 27, 'max_depth': 4}. Best is trial 21 with value: 0.5664930016803386.
# [I 2025-12-25 11:05:49,145] Trial 73 finished with value: 0.565903166444165 and parameters: {'n_estimators': 30, 'max_depth': 6}. Best is trial 73 with value: 0.565903166444165.
# [I 2025-12-25 11:05:49,306] Trial 74 finished with value: 0.5813025930872263 and parameters: {'n_estimators': 32, 'max_depth': 6}. Best is trial 73 with value: 0.565903166444165.
# [I 2025-12-25 11:05:49,529] Trial 75 finished with value: 0.5731916005312568 and parameters: {'n_estimators': 48, 'max_depth': 5}. Best is trial 73 with value: 0.565903166444165.
# [I 2025-12-25 11:05:49,730] Trial 76 finished with value: 0.5696887581180519 and parameters: {'n_estimators': 41, 'max_depth': 6}. Best is trial 73 with value: 0.565903166444165.
# [I 2025-12-25 11:05:50,595] Trial 77 finished with value: 0.5795024465470225 and parameters: {'n_estimators': 159, 'max_depth': 10}. Best is trial 73 with value: 0.565903166444165.
# [I 2025-12-25 11:05:51,357] Trial 78 finished with value: 0.581783928415688 and parameters: {'n_estimators': 188, 'max_depth': 5}. Best is trial 73 with value: 0.565903166444165.
# [I 2025-12-25 11:05:51,695] Trial 79 finished with value: 0.5860269283039444 and parameters: {'n_estimators': 61, 'max_depth': 17}. Best is trial 73 with value: 0.565903166444165.
# [I 2025-12-25 11:05:52,750] Trial 80 finished with value: 0.57238357973974 and parameters: {'n_estimators': 200, 'max_depth': 9}. Best is trial 73 with value: 0.565903166444165.
# [I 2025-12-25 11:05:52,875] Trial 81 finished with value: 0.5658144802610567 and parameters: {'n_estimators': 30, 'max_depth': 4}. Best is trial 81 with value: 0.5658144802610567.
# [I 2025-12-25 11:05:53,006] Trial 82 finished with value: 0.5660994103990088 and parameters: {'n_estimators': 34, 'max_depth': 3}. Best is trial 81 with value: 0.5658144802610567.
# [I 2025-12-25 11:05:53,135] Trial 83 finished with value: 0.5738732029791204 and parameters: {'n_estimators': 34, 'max_depth': 3}. Best is trial 81 with value: 0.5658144802610567.
# [I 2025-12-25 11:05:53,241] Trial 84 finished with value: 0.5794358455803439 and parameters: {'n_estimators': 24, 'max_depth': 4}. Best is trial 81 with value: 0.5658144802610567.
# [I 2025-12-25 11:05:53,440] Trial 85 finished with value: 0.5715252692048768 and parameters: {'n_estimators': 54, 'max_depth': 3}. Best is trial 81 with value: 0.5658144802610567.
# [I 2025-12-25 11:05:53,613] Trial 86 finished with value: 0.5792161400300732 and parameters: {'n_estimators': 43, 'max_depth': 4}. Best is trial 81 with value: 0.5658144802610567.
# [I 2025-12-25 11:05:53,733] Trial 87 finished with value: 0.5884820568511504 and parameters: {'n_estimators': 31, 'max_depth': 3}. Best is trial 81 with value: 0.5658144802610567.
# [I 2025-12-25 11:05:53,822] Trial 88 finished with value: 0.6000888881126915 and parameters: {'n_estimators': 24, 'max_depth': 2}. Best is trial 81 with value: 0.5658144802610567.
# [I 2025-12-25 11:05:54,000] Trial 89 finished with value: 0.5626973622166126 and parameters: {'n_estimators': 40, 'max_depth': 5}. Best is trial 89 with value: 0.5626973622166126.
# [I 2025-12-25 11:05:54,194] Trial 90 finished with value: 0.5796696532128478 and parameters: {'n_estimators': 40, 'max_depth': 5}. Best is trial 89 with value: 0.5626973622166126.
# [I 2025-12-25 11:05:54,383] Trial 91 finished with value: 0.5741753506844741 and parameters: {'n_estimators': 36, 'max_depth': 7}. Best is trial 89 with value: 0.5626973622166126.
# [I 2025-12-25 11:05:54,497] Trial 92 finished with value: 0.5728021741587731 and parameters: {'n_estimators': 27, 'max_depth': 4}. Best is trial 89 with value: 0.5626973622166126.
# [I 2025-12-25 11:05:54,978] Trial 93 finished with value: 0.5724289556761514 and parameters: {'n_estimators': 110, 'max_depth': 5}. Best is trial 89 with value: 0.5626973622166126.
# [I 2025-12-25 11:05:55,164] Trial 94 finished with value: 0.5741405903127413 and parameters: {'n_estimators': 45, 'max_depth': 4}. Best is trial 89 with value: 0.5626973622166126.
# [I 2025-12-25 11:05:55,770] Trial 95 finished with value: 0.5867001815465002 and parameters: {'n_estimators': 137, 'max_depth': 6}. Best is trial 89 with value: 0.5626973622166126.
# [I 2025-12-25 11:05:56,021] Trial 96 finished with value: 0.5842047972286585 and parameters: {'n_estimators': 58, 'max_depth': 5}. Best is trial 89 with value: 0.5626973622166126.
# [I 2025-12-25 11:05:56,111] Trial 97 finished with value: 0.5967579141132734 and parameters: {'n_estimators': 21, 'max_depth': 3}. Best is trial 89 with value: 0.5626973622166126.
# [I 2025-12-25 11:05:56,582] Trial 98 finished with value: 0.5657745380400782 and parameters: {'n_estimators': 124, 'max_depth': 4}. Best is trial 89 with value: 0.5626973622166126.
# [I 2025-12-25 11:05:56,863] Trial 99 finished with value: 0.5709915733610603 and parameters: {'n_estimators': 70, 'max_depth': 4}. Best is trial 89 with value: 0.5626973622166126.

# %%
study.best_params
# Out:
# {'n_estimators': 40, 'max_depth': 5}

# %%
study.best_value
# Out:
# 0.5626973622166126

# %%
from sklearn.metrics import mean_squared_error

forrest = RandomForestRegressor(**study.best_params)
forrest.fit(_X_train, _y_train)

y_pred = forrest.predict(_X_test)

mse_test = mean_squared_error(y_pred, _y_test)

# %%
mse_test
# Out:
# 0.45782707160965735
